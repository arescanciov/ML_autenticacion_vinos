# %% [markdown]
# # Notebook de desarrollo / pruebas
#
# Espacio de trabajo para pruebas exploratorias y borradores que **no forman
# parte del pipeline final**. El pipeline completo y limpio vive en `main.ipynb`,
# en la raíz del repositorio.

# %%
import sys
sys.path.append("../../src")

from sklearn.datasets import load_wine
data = load_wine(as_frame=True)
data.frame.head()
